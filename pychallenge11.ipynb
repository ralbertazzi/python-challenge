# %% [markdown]
# # Problem 11
#
# Odd, even
#
# http://www.pythonchallenge.com/pc/return/5808.html

# %%
import matplotlib.pyplot as plt
from utils.web import get_image_from_url

# %%
image = get_image_from_url('http://www.pythonchallenge.com/pc/return/cave.jpg', username='huge', password='file')
plt.imshow(image)

# %%
plt.imshow(image[::2, ::2, :])
